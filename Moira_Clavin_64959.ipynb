# %% [markdown]
# <a href="https://colab.research.google.com/github/moiraclavin/An-lisis-Predictivo/blob/main/Moira_Clavin_64959.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Examen 3 - Análisis Predictivo**
# ## Moira Patricia Clavin
# Legajo: 64959
# Fecha de entrega: 17/06/26
#
#
#
# ---

# %% [markdown]
# 1. **Importación y primera vista**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/moirapatriciaclavin/base-train-csv/base_train.csv
# /kaggle/input/competitions/ap2026q1/base_val.csv
# /kaggle/input/competitions/ap2026q1/base_train.csv

# %%
df = pd.read_csv('/kaggle/input/competitions/ap2026q1/base_train.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0                                           track_id  \
# 0            0  RElEdzDz0jD/AyKJjcfulWEzXE0kFpXmh4bXv+Y7ULB1Te...
# 1            1  C/gTxHQyIA9QiUKErgUfcS4Hazv579AlBoZ9oLvF6cuICX...
# 2            2  zBrCGicZsUMewr2V/Wzh/fQNTH+mcjXNtePfJoOLgW8VXo...
# 3            3  +MSXXbogejelwq6wZ+E3w/Zv3nh3umVA1H+Ab0GFp70Elg...
# 4            4  jCcYIsqs6knl1+5WHL596AZrxduU8BHVNtvgDIDqp8hV7D...
# 5            5  A0OyqCG2Vz7tX0ynpnz7/ZisNz5klIGp9QtqWFxf6r9S2q...
# 6            6  v1tTLBwQ6mADrUci39cqq2fp7iJygbvX+mDJjAhgb2HUfl...
# 7            7  jmmJdsKpcQ9pH3Lhk/9j1bJY/H8dSKNPR2X5jXbMbXZ4cv...
# 8            8  IDYYYyOglGVXcs0Hhte04WsiUVk7N5H/CIjFQDwlMLX2MO...
# 9            9  73gkgoYkgHYJTb7aV/q/Fd6LNa8vt8aLzzgQ4rWQd32iZr...
# 10          10  HcWOcydhyJcVD+j+9pdQIqqvdq70p0FLmb8dDsWs7SKPML...
# 11          11  nUaj7J21f9Yf2IztRb2BoBN7wU6i0MSAej5cAEstc1A0cI...
# 12          12  bOUzgTRl9FpvdZqbFwvzSldAeu644joKOTLgEPUBtVdrRV...
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  track_popularity  danceability        energy  \
# count  26266.000000      26266.000000  26266.000000  26266.000000
# mean   13132.500000         44.543326      0.655715      0.677818
# std     7582.485421         24.992724      0.149557      0.179567
# min        0.000000          0.000000      0.000000      0.000175
# 25%     6566.250000         27.000000      0.559000      0.560000
# 50%    13132.500000         48.000000      0.676000      0.698000
# 75%    19698.750000         64.000000      0.766000      0.817000
# max    26265.000000        100.000000      0.979000      1.000000
#
#                 key      loudness          mode   speechiness  acousticness  \
# count  26266.000000  26266.000000  26266.000000  26266.000000  26266.000000
# mean       5.377522     -6.983105      0.577972      0.111788      0.193761
# std        3.626019      3.027421      0.493892      0.106399      0.225929
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26266 entries, 0 to 26265
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                26266 non-null  int64
#  1   track_id                  26266 non-null  object
#  2   track_name                26261 non-null  object
#  3   track_artist              26261 non-null  object
#  4   track_popularity          26266 non-null  int64
#  5   track_album_id            26266 non-null  object
#  6   track_album_name          26261 non-null  object
#  7   track_album_release_date  26266 non-null  object
#  8   playlist_name             26266 non-null  object
#  9   playlist_id               26266 non-null  object
#  10  playlist_genre            26266 non-null  object
#  11  playlist_subgenre         26266 non-null  object
#  12  danceability              26266 non-null  float64
# ...

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'track_popularity'}>,
#         <Axes: title={'center': 'danceability'}>,
#         <Axes: title={'center': 'energy'}>],
#        [<Axes: title={'center': 'key'}>,
#         <Axes: title={'center': 'loudness'}>,
#         <Axes: title={'center': 'mode'}>,
#         <Axes: title={'center': 'speechiness'}>],
#        [<Axes: title={'center': 'acousticness'}>,
#         <Axes: title={'center': 'instrumentalness'}>,
#         <Axes: title={'center': 'liveness'}>,
#         <Axes: title={'center': 'valence'}>],
#        [<Axes: title={'center': 'tempo'}>,
#         <Axes: title={'center': 'duration_ms'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# !! Dummy submit

# %%
df_val = pd.read_csv('/kaggle/input/competitions/ap2026q1/base_val.csv')

# %%
y_pred = [0] * len(df_val)

# %%
submission = pd.DataFrame({
    "ID": df_val.iloc[:, 0],   # mayúsculas
    "target": y_pred
})

# %%
submission.to_csv('/kaggle/working/submission.csv', index=False)
